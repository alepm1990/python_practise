# %%
urls = ["https://www.lighting.philips.com/content/b2b-philips-lighting/vn/vi/products/highlighted-products/ledstrips",
       "https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/support/cases/airports/schiphol-airport",
        "https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/products/highlighted-products/ledstrips",
        "https://www.lighting.philips.com/content/b2b-philips-lighting/vn/vi/products/highlighted-products/maxos-fusion",
        "https://www.as.com",
        "https://www.eldiario.es/internacional/terremoto-magnitud-8-8-frente-peninsula-rusa-kamchatka-desata-alertas-tsunami-pacifico_1_12501817.html",
        "https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/application-areas/public-spaces/recreational-sports/outdoor-sports"
]

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Usuario/Documents/marketo_python/urls_pageviews.csv")
df.head(5)
# Out:
#                                                 urls
# 0  https://www.lighting.philips.com/content/b2b-p...
# 1  https://www.lighting.philips.com/content/b2b-p...
# 2  https://www.lighting.philips.com/content/b2b-p...
# 3  https://www.lighting.philips.com/content/b2b-p...
# 4  https://www.lighting.philips.com/content/b2b-p...

# %%
urls = df["urls"].iloc[:58].tolist()

# %%
import asyncio
import nest_asyncio
import csv
from playwright.async_api import async_playwright

nest_asyncio.apply()

# Lista de URLs a revisar


async def revisar_pagina(page, url):
    print(f"\n🌐 Revisando: {url}")
    error_404_detectado = False
    munchkin_detectado = False

    async def manejar_respuesta(response):
        nonlocal error_404_detectado
        if response.status == 404:
            print(f"❌ Recurso 404 detectado: {response.url}")
            error_404_detectado = True

    def manejar_request(request):
        nonlocal munchkin_detectado
        if "munchkin.js" in request.url:
            print(f"📦 Munchkin code detectado: {request.url}")
            munchkin_detectado = True

    page.on("response", manejar_respuesta)
    page.on("request", manejar_request)

    try:
        await page.goto(url, timeout=20000)
        await page.wait_for_timeout(3000)
    except Exception as e:
        print(f"⚠️ Error al cargar la página: {e}")
        return {"url": url, "error_404_detectado": True, "munchkin_detectado": munchkin_detectado}

    return {
        "url": url,
        "error_404_detectado": error_404_detectado,
        "munchkin_detectado": munchkin_detectado
    }

async def main():
    resultados = []

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        context = await browser.new_context()

        # Pestaña en blanco que permanece abierta
        pestana_principal = await context.new_page()
        paginas_abiertas = [pestana_principal]

        for url in urls:
            nueva_pestana = await context.new_page()
            paginas_abiertas.append(nueva_pestana)

            if len(paginas_abiertas) > 2:
                anterior = paginas_abiertas.pop(1)
                await anterior.close()

            resultado = await revisar_pagina(nueva_pestana, url)
            resultados.append(resultado)

        print("\n📝 Guardando resultados...")

        with open("resultados_munchkin_pageview3.csv", mode="w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=["url", "error_404_detectado", "munchkin_detectado"])
            writer.writeheader()
            writer.writerows(resultados)

        print("✅ Resultados guardados en 'resultados_munchkin_pageview3.csv'")


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/my/en/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/application-areas/public-spaces/airports/air-side
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/application-areas/office-industry/office/cri90-upgrade-professional-luminaire
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ph/en/application-areas/office-industry/healthcare
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ca/en/application-areas/specialist-applications/horticulture/medicinal-cannabis/philips-led-recipe-provides-optimal-propagation-of-cannabis-plants
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ca/en/application-areas/specialist-applications/horticulture/cannabis/philips-led-recipe-provides-optimal-propagation-of-cannabis-plants
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ch/de/support/cases/airports/schiphol-airport
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ch/fr/application-areas/retail-hospitality/fruits-vegetables
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ch/fr/application-areas/specialist-applications/horticulture
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/expert-view/lass-light-as-a-service
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/expert-view/disinfection-uvc
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/light-in-business/grocery-store-and-supermarket-lighting
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/city-of-light/city-lighting-modernization
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/light-in-business/lighting-warehouse-standards-requirements
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/light-in-business/lamps-and-industrial-luminaires
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/city-of-light/park-lamps
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/city-of-light/smart-city-starts-with-lighting
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/hu/hu/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/hu/hu/support/cases/airports/schiphol-airport
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ro/ro/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/sk/sk/application-areas/retail-hospitality/fruits-vegetables
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/bg/bg/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/city-of-light/architectural-facade-lighting-design
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/application-areas/public-spaces/bridges-monuments-facades
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/application-areas/retail-hospitality/malls
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/education/fluorescent-lamps-will-be-phased-out-of-the-eu
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/light-in-business/replacement-and-modernization-of-lighting
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pl/pl/support/blog/education/the-tti-ee-company-invests-in-disinfection-devices
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/aa/en/application-areas/specialist-applications/uv-disinfection
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/hk/en/application-areas/public-spaces/recreational-sports/outdoor-sports
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/es/es/application-areas/specialist-applications/solar
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/es/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/growing-great-tasting-tomatoes-with-led-lighting
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/es/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light-part-2
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pe/es/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pe/es/support/cases/airports/schiphol-airport
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/co/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/co/es/application-areas/specialist-applications/horticulture/hortiblog/vertical-farming/growing-top-quality-tomatoes-in-a-vertical-farm
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ar/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pe/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/pe/es/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/growing-great-tasting-tomatoes-with-led-lighting
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ae/en/application-areas/retail-hospitality/fruits-vegetables
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ae/en/support/hubs/partners/architainment
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/no/no/support/cases/airports/schiphol-airport
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/no/no/application-areas/retail-hospitality/fruits-vegetables
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/no/no/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/se/sv/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/se/sv/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light-part-2
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/se/sv/application-areas/specialist-applications/horticulture/hortiblog/vertical-farming/growing-top-quality-tomatoes-in-a-vertical-farm
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/dk/da/application-areas/public-spaces/recreational-sports
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/nz/en/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/au/en/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/myth-surrounding-white-light
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/ie/en/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/growing-great-tasting-tomatoes-with-led-lighting
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/us/en/application-areas/specialist-applications/horticulture/hortiblog/light-and-growth/proven-results-of-led-interlighting-for-high-wire-cultivation
# 📦 Munchkin code detectado: https://munchkin.marketo.net/munchkin.js
# 📦 Munchkin code detectado: https://munchkin.marketo.net/164/munchkin.js
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/us/en/application-areas/specialist-applications/horticulture/medicinal-cannabis/philips-led-recipe-provides-optimal-propagation-of-cannabis-plants
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/us/en/application-areas/specialist-applications/horticulture/cannabis/philips-led-recipe-provides-optimal-propagation-of-cannabis-plants
#
# 🌐 Revisando: https://www.lighting.philips.com/content/b2b-philips-lighting/us/en/application-areas/specialist-applications/uv-disinfection
#
# 📝 Guardando resultados...
# ✅ Resultados guardados en 'resultados_munchkin_pageview3.csv'
